# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

# %%
pwd
# Out:
# '/ewsc/exxact04/vshir/tcga'

# %%
labelled_data = pd.read_pickle('pkl/GI_cluster50_labelled_all_mar28.pkl') #data containing the cluster labels for each point

# %%
all_slide_ids = pd.read_pickle('pkl/GI_allslide_IDs_02_18_26.pkl') #list of all the slide IDs

# %%
cancer_types = ['paad','coad','esca','stad','read']

# %%
labelled_data.head()
# Out:
#                                                           label     X      Y
# paad TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC89... 0     0  1792  11264
#                                                         1     0  1792  11520
#                                                         2    46  2048   9984
#                                                         3    46  2048  10240
#                                                         4    46  2048  10496

# %%
labelled_data.index.set_names(['cancer_type', 'tcga_id', 'number'], inplace=True)
labelled_data = labelled_data[labelled_data.index.get_level_values('cancer_type') != 'luad']

# %%
labelled_data
# Out:
#                                                                       label  \
# cancer_type tcga_id                                            number
# paad        TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC89... 0          0
#                                                                1          0
#                                                                2         46
#                                                                3         46
#                                                                4         46
# ...                                                                     ...
# read        TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-9352... 36609     13
#                                                                36610     29
#                                                                36611     29
#                                                                36612     13
#                                                                36613     13
#
#                                                                            X  \
# cancer_type tcga_id                                            number
# paad        TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC89... 0        1792
#                                                                1        1792
#                                                                2        2048
#                                                                3        2048
#                                                                4        2048
# ...                                                                      ...
# read        TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-9352... 36609   94208
#                                                                36610   94208
#                                                                36611   94208
#                                                                36612   94208
#                                                                36613   94208
#
#                                                                            Y
# cancer_type tcga_id                                            number
# paad        TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC89... 0       11264
#                                                                1       11520
#                                                                2        9984
#                                                                3       10240
#                                                                4       10496
# ...                                                                      ...
# read        TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-9352... 36609   20736
#                                                                36610   20992
#                                                                36611   21248
#                                                                36612   21504
#                                                                36613   21760
#
# [58780353 rows x 3 columns]

# %%
# Group by the label column and count occurrences
label_distribution = labelled_data.groupby('label').size().reset_index(name='counts')

label_distribution
# Out:
# /tmp/ipykernel_3734467/2491669985.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   label_distribution = labelled_data.groupby('label').size().reset_index(name='counts')
#    label   counts
# 0      0  1184131
# 1      1  1006797
# 2      2   767909
# 3      3  1589054
# 4      4  1644894
# 5      5   923986
# 6      6  1896491
# 7      7   718965
# 8      8  2435551
# 9      9  1009464
# 10    10   924916
# 11    11  1191772
# 12    12  1349561
# 13    13  1802879
# 14    14  1005567
# 15    15  1362340
# 16    16  1459425
# 17    17  1374192
# 18    18   639693
# 19    19  1473787
# 20    20  1107479
# 21    21   685101
# 22    22  1975753
# 23    23  2254747
# 24    24  1248682
# 25    25  1256612
# 26    26  1199299
# 27    27   380703
# 28    28   668870
# 29    29   900337
# 30    30  1321367
# 31    31   492550
# 32    32  1244790
# 33    33  1125420
# 34    34   176702
# 35    35   408264
# 36    36  1477400
# 37    37   633911
# 38    38  1181101
# 39    39  1001964
# 40    40   757515
# 41    41  1516252
# 42    42  1185242
# 43    43  1022197
# 44    44   745727
# 45    45  1382109
# 46    46  2301607
# 47    47  1063991
# 48    48  1356563
# 49    49   946724

# %%
# 1. Create the plot
# We convert 'label' to string so matplotlib treats them as discrete categories
plt.bar(label_distribution['label'].astype(str), label_distribution['counts'], color='skyblue')

# 2. Add Axis Labels and Title
plt.xlabel('Label', fontsize=12)    # X-axis label
plt.ylabel('Counts', fontsize=12)   # Y-axis counts
plt.title('Label Distribution', fontsize=14)

# 3. Optional: Improve readability
# If you have many labels, rotating them prevents overlap
plt.xticks(fontsize =6)

# Adjust layout to make sure labels aren't cut off
plt.tight_layout()

# 4. Display the plot
plt.show()

# %%
df_counts = labelled_data.groupby(level=['cancer_type', 'tcga_id']).size().reset_index(name='label_count')
df_counts
# Out:
#      cancer_type                                            tcga_id  \
# 0           coad  TCGA-3L-AA1B-01Z-00-DX1.8923A151-A690-40B7-9E5...
# 1           coad  TCGA-3L-AA1B-01Z-00-DX2.17CE3683-F4B1-4978-A28...
# 2           coad  TCGA-4N-A93T-01Z-00-DX2.875E7F95-A6D4-4BEB-A33...
# 3           coad  TCGA-4T-AA8H-01Z-00-DX1.A46C759C-74A2-4724-B6B...
# 4           coad  TCGA-5M-AAT4-01Z-00-DX1.725C46CA-9354-43AC-AA8...
# ...          ...                                                ...
# 1306        stad  TCGA-VQ-AA6I-01Z-00-DX1.B11762F9-1DA7-4140-8F4...
# 1307        stad  TCGA-VQ-AA6J-01Z-00-DX1.212AF324-26E9-4807-A64...
# 1308        stad  TCGA-VQ-AA6K-01Z-00-DX1.8AF14797-0C31-4DF3-94A...
# 1309        stad  TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817...
# 1310        stad  TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7A...
#
#       label_count
# 0           59070
# 1           31893
# 2           90902
# 3          100485
# 4          100221
# ...           ...
# 1306        69068
# 1307        65341
# 1308         3549
# 1309        28795
# 1310        88838
#
# [1311 rows x 3 columns]

# %%
df_counts['label_count'].mean()
# Out:
# np.float64(44836.272311212815)

# %%
df_summary = labelled_data.groupby(level=['cancer_type', 'tcga_id']).agg(
    label_count=('label', 'size'),
    dim_x=('X', lambda x: x.max() - x.min()),
    dim_y=('Y', lambda y: y.max() - y.min())
).reset_index()

df_summary
# Out:
#      cancer_type                                            tcga_id  \
# 0           coad  TCGA-3L-AA1B-01Z-00-DX1.8923A151-A690-40B7-9E5...
# 1           coad  TCGA-3L-AA1B-01Z-00-DX2.17CE3683-F4B1-4978-A28...
# 2           coad  TCGA-4N-A93T-01Z-00-DX2.875E7F95-A6D4-4BEB-A33...
# 3           coad  TCGA-4T-AA8H-01Z-00-DX1.A46C759C-74A2-4724-B6B...
# 4           coad  TCGA-5M-AAT4-01Z-00-DX1.725C46CA-9354-43AC-AA8...
# ...          ...                                                ...
# 1306        stad  TCGA-VQ-AA6I-01Z-00-DX1.B11762F9-1DA7-4140-8F4...
# 1307        stad  TCGA-VQ-AA6J-01Z-00-DX1.212AF324-26E9-4807-A64...
# 1308        stad  TCGA-VQ-AA6K-01Z-00-DX1.8AF14797-0C31-4DF3-94A...
# 1309        stad  TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817...
# 1310        stad  TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7A...
#
#       label_count   dim_x  dim_y
# 0           59070   90368  70912
# 1           31893   82432  48128
# 2           90902   94720  88576
# 3          100485  101888  78592
# 4          100221  105728  88832
# ...           ...     ...    ...
# 1306        69068   92416  89344
# 1307        65341   80384  87808
# 1308         3549   23552  25344
# 1309        28795   42240  56576
# 1310        88838  108544  82688
#
# [1311 rows x 5 columns]

# %%
df_summary['dim_x'].mean()
# Out:
# np.float64(80771.80778032036)

# %%
df_summary['dim_y'].mean()
# Out:
# np.float64(60009.05568268497)

# %%
index_df
# Out:
#          cancer_type                                            tcga_id
# 0               paad  TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC8...
# 1               paad  TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC8...
# 2               paad  TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC8...
# 3               paad  TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC8...
# 4               paad  TCGA-HZ-A9TJ-01Z-00-DX1.CB2953B6-9601-4300-BC8...
# ...              ...                                                ...
# 85078329        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 85078330        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 85078331        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 85078332        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 85078333        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
#
# [85078334 rows x 2 columns]

# %%
# 1. Convert the MultiIndex to a DataFrame of just the index levels
index_df = labelled_data.index.to_frame(index=False)[['cancer_type', 'tcga_id']]
index_df = index_df[index_df['cancer_type']!='luad']
# 2. Drop duplicates so you have exactly one row per slide
unique_slides = index_df.drop_duplicates()

# 3. Count how many slides belong to each cancer type
cancer_type_counts = unique_slides['cancer_type'].value_counts()

cancer_type_counts
# Out:
# cancer_type
# stad    398
# coad    396
# paad    209
# read    158
# esca    150
# Name: count, dtype: int64

# %%
label_counts = labelled_data.groupby('tcga_id')['label'].value_counts().unstack(fill_value=0)
all_labels = list(range(50))
label_counts = label_counts.reindex(columns=all_labels, fill_value=0)

# %%
label_counts
# Out:
# label                                                  0     1     2   3   4   \
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...     51   116  1577   0   0
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...     59    68     9   0   0
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...     48     2    16   1   1
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...     71    58    45   0   0
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...     34     0     2   0   0
# ...                                                   ...   ...   ...  ..  ..
# TCGA-Z6-A9VB-01Z-00-DX1.D35A32ED-DFEE-4070-9542...      0   685   174   0   0
# TCGA-Z6-AAPN-01Z-00-DX1.345F7431-CD48-40DB-89D6...      1  1533    75   0   0
# TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817E...      1   420    15   0   0
# TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7AA...   3062     0     0   2   0
# TCGA-ZR-A9CJ-01Z-00-DX1.4A1AE826-FB78-4DD3-8814...  13235     0     8  39   0
#
# label                                                5     6    7      8   \
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...   32  3485   16      1
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...    1   361   96      1
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...    0    30  152      0
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...    0   133    4      0
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...    0   118   15      0
# ...                                                 ...   ...  ...    ...
# TCGA-Z6-A9VB-01Z-00-DX1.D35A32ED-DFEE-4070-9542...  627   177    1      0
# TCGA-Z6-AAPN-01Z-00-DX1.345F7431-CD48-40DB-89D6...  337  2036   28      0
# TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817E...  336  5471  464      0
# TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7AA...    0     0   49  25247
# TCGA-ZR-A9CJ-01Z-00-DX1.4A1AE826-FB78-4DD3-8814...    0     0    6  18893
#
# label                                                  9   ...    40     41  \
# tcga_id                                                    ...
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...    259  ...   662  26309
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...   3099  ...    12   1199
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...   3559  ...   133    490
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...  19826  ...   489    365
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...   2096  ...   274      5
# ...                                                   ...  ...   ...    ...
# TCGA-Z6-A9VB-01Z-00-DX1.D35A32ED-DFEE-4070-9542...      2  ...     0    229
# TCGA-Z6-AAPN-01Z-00-DX1.345F7431-CD48-40DB-89D6...      0  ...     2  14805
# TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817E...      2  ...   549   3058
# TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7AA...      0  ...  3728      0
# TCGA-ZR-A9CJ-01Z-00-DX1.4A1AE826-FB78-4DD3-8814...      0  ...    46      0
#
# label                                                 42    43   44   45  \
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...  6627    22  587    0
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...  2642  8275  133    0
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...    37    84   76    1
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...   519     6  108    0
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...   373     4   64    0
# ...                                                  ...   ...  ...  ...
# TCGA-Z6-A9VB-01Z-00-DX1.D35A32ED-DFEE-4070-9542...   346     1  915    0
# TCGA-Z6-AAPN-01Z-00-DX1.345F7431-CD48-40DB-89D6...   636     6  196    1
# TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817E...   832  1125    3    0
# TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7AA...     1   291    0   48
# TCGA-ZR-A9CJ-01Z-00-DX1.4A1AE826-FB78-4DD3-8814...     2  3833    0  111
#
# label                                                 46    47     48    49
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...  2806  3975  17179   852
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...  1013  8740   9961     0
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...   980  4105   9413  1473
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...  1724   366   7354   749
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...  2220  8728  28492   244
# ...                                                  ...   ...    ...   ...
# TCGA-Z6-A9VB-01Z-00-DX1.D35A32ED-DFEE-4070-9542...  2155    37   4502     7
# TCGA-Z6-AAPN-01Z-00-DX1.345F7431-CD48-40DB-89D6...  7343   297      0    62
# TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817E...  3080   239      0  8192
# TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7AA...    12     0      0   292
# TCGA-ZR-A9CJ-01Z-00-DX1.4A1AE826-FB78-4DD3-8814...    18     9      0   733
#
# [1311 rows x 50 columns]

# %%
label_counts['total'] = label_counts.loc[:, 0:49].sum(axis=1)

# %%
label_counts.head()
# Out:
# label                                                0    1     2  3  4   5  \
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...  51  116  1577  0  0  32
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...  59   68     9  0  0   1
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...  48    2    16  1  1   0
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...  71   58    45  0  0   0
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...  34    0     2  0  0   0
#
# label                                                  6    7  8      9  ...  \
# tcga_id                                                                  ...
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...  3485   16  1    259  ...
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...   361   96  1   3099  ...
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...    30  152  0   3559  ...
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...   133    4  0  19826  ...
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...   118   15  0   2096  ...
#
# label                                                  41    42    43   44  \
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...  26309  6627    22  587
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...   1199  2642  8275  133
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...    490    37    84   76
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...    365   519     6  108
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...      5   373     4   64
#
# label                                               45    46    47     48  \
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...   0  2806  3975  17179
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...   0  1013  8740   9961
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...   1   980  4105   9413
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...   0  1724   366   7354
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...   0  2220  8728  28492
#
# label                                                 49   total
# tcga_id
# TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77B...   852  111126
# TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96CB...     0   70962
# TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A205...  1473   38161
# TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B396...   749   75217
# TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B367...   244   76903
#
# [5 rows x 51 columns]

# %%
label_counts['total'].mean()
# Out:
# np.float64(44836.272311212815)

# %%
plt.hist(label_counts['total'])
# Out:
# (array([345., 176., 187., 225., 187., 105.,  55.,  23.,   6.,   2.]),
#  array([   864. ,  16399.7,  31935.4,  47471.1,  63006.8,  78542.5,
#          94078.2, 109613.9, 125149.6, 140685.3, 156221. ]),
#  <BarContainer object of 10 artists>)

# %%
test_slide_ids = labelled_data.loc['coad'].sample(10, random_state=4).index.unique()

# %%
test_slide_ids
# Out:
# MultiIndex([('TCGA-F4-6460-01Z-00-DX1.92a182ea-f22a-4d74-bfb6-34d3cd757dce', ...),
#             ('TCGA-A6-3807-01Z-00-DX1.c3de2064-4f8d-4786-9ff9-2e0f44293717', ...),
#             ('TCGA-AA-3971-01Z-00-DX1.348b1114-a9d5-4a37-8dfd-3bc8738fec35', ...),
#             ('TCGA-AA-3710-01Z-00-DX1.78082263-b7e9-4281-aa55-2da5f80e4499', ...),
#             ('TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f2-0dc195a3d7df', ...),
#             ('TCGA-G4-6315-01Z-00-DX1.2c3c17b0-c118-42b1-b1c9-7cc984e47f6c', ...),
#             ('TCGA-CK-5912-01Z-00-DX1.23a955f3-a1ed-4cb3-8e49-cbb3f789f3f5', ...),
#             ('TCGA-AZ-6601-01Z-00-DX1.40681471-3104-48be-8b57-55dba1f432f8', ...),
#             ('TCGA-AZ-4681-01Z-00-DX1.e468c1a1-e251-4521-82fe-526c9c5f8190', ...),
#             ('TCGA-G4-6322-01Z-00-DX1.8676af67-716a-4052-a5e7-024b2e29c492', ...)],
#            names=['tcga_id', 'number'])

# %%
sns.scatterplot(data = labelled_data.loc['coad'].loc['TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f2-0dc195a3d7df'], x = 'X', y = 'Y', hue = 'label',s = 2,legend = False,palette = 'bright') 
plt.show()

# %%
sample_df = labelled_data.loc['coad'].loc['TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f2-0dc195a3d7df']
sample_df
# Out:
#        label      X      Y
# number
# 0         34      0  37632
# 1          0      0  37888
# 2          0      0  38144
# 3          0      0  38400
# 4         25      0  38656
# ...      ...    ...    ...
# 62406      0  79616  40960
# 62407     46  79616  41216
# 62408     36  79616  41472
# 62409     46  79616  41728
# 62410     46  79616  41984
#
# [62411 rows x 3 columns]

# %%
sample_df['label'].value_counts()[0]
# Out:
# np.int64(6765)

# %%
#Function for one slide
from itertools import combinations

# 1. Map Coordinates to Labels
coord_label_map = dict(zip(zip(sample_df['X'], sample_df['Y']), sample_df['label']))

# 2. Setup
stride = 256
offsets = [
    (stride, 0), (-stride, 0), (0, stride), (0, -stride),
    (stride, stride), (-stride, -stride), (stride, -stride), (-stride, stride)
]

num_clusters = 50
contact_matrix = np.zeros((num_clusters, num_clusters), dtype=int)

# 3. Iterate through all coordinates
for (x, y), label_center in coord_label_map.items():
    for dx, dy in offsets:
        neighbor_coord = (x + dx, y + dy)
        
        if neighbor_coord in coord_label_map:
            label_neighbor = coord_label_map[neighbor_coord]
            contact_matrix[label_center, label_neighbor] += 1 

# 4. Compile Results for unique pairs only (1,225 rows)
results = []
cluster_totals = sample_df['label'].value_counts().reindex(range(num_clusters), fill_value=0)  

# itertools.combinations(range(50), 2) gives exactly 1,225 pairs
for c1, c2 in combinations(range(num_clusters), 2):
    contact_count = contact_matrix[c1, c2] 
    c1_total_points = contact_matrix[c1, :].sum() 
    
    results.append({
        'cluster 1': c1,
        'cluster 2': c2,
        'contact count': contact_count,
        'total cluster 1': sample_df['label'].value_counts()[c1],
        'total cluster 2': sample_df['label'].value_counts()[c2],
        'total cluster 1 interactions': c1_total_points,
        'frequency': contact_count / c1_total_points if c1_total_points > 0 else 0
    })

contact_df = pd.DataFrame(results)

# %%
contact_matrix[0,25]
# Out:
# np.int64(5208)

# %%
contact_matrix[25,0]
# Out:
# np.int64(5208)

# %%
contact_matrix[c1, :].sum()
# Out:
# np.int64(4548)

# %%
contact_matrix[:,c1].sum()
# Out:
# np.int64(4548)

# %%
contact_df
# Out:
#       cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 0             0          1              0             6765                5
# 1             0          2             10             6765              291
# 2             0          3              0             6765                0
# 3             0          4              0             6765                0
# 4             0          5              0             6765               12
# ...         ...        ...            ...              ...              ...
# 1220         46         48             51             1323              569
# 1221         46         49            381             1323             6993
# 1222         47         48            109             4152              569
# 1223         47         49           1210             4152             6993
# 1224         48         49             12              569             6993
#
#       total cluster 1 interactions  frequency
# 0                            53051   0.000000
# 1                            53051   0.000188
# 2                            53051   0.000000
# 3                            53051   0.000000
# 4                            53051   0.000000
# ...                            ...        ...
# 1220                          9319   0.005473
# 1221                          9319   0.040884
# 1222                         32788   0.003324
# 1223                         32788   0.036904
# 1224                          4548   0.002639
#
# [1225 rows x 7 columns]

# %%
ratio = contact_df['total cluster 1 interactions']/contact_df['total cluster 1']
ratio
# Out:
# 0       7.841981
# 1       7.841981
# 2       7.841981
# 3       7.841981
# 4       7.841981
#           ...
# 1220    7.043840
# 1221    7.043840
# 1222    7.896917
# 1223    7.896917
# 1224    7.992970
# Length: 1225, dtype: float64

# %%
contact_df['ratio'] = ratio 
contact_df
# Out:
#       cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 0             0          1              0             6765                5
# 1             0          2             10             6765              291
# 2             0          3              0             6765                0
# 3             0          4              0             6765                0
# 4             0          5              0             6765               12
# ...         ...        ...            ...              ...              ...
# 1220         46         48             51             1323              569
# 1221         46         49            381             1323             6993
# 1222         47         48            109             4152              569
# 1223         47         49           1210             4152             6993
# 1224         48         49             12              569             6993
#
#       total cluster 1 interactions  frequency     ratio
# 0                            53051   0.000000  7.841981
# 1                            53051   0.000188  7.841981
# 2                            53051   0.000000  7.841981
# 3                            53051   0.000000  7.841981
# 4                            53051   0.000000  7.841981
# ...                            ...        ...       ...
# 1220                          9319   0.005473  7.043840
# 1221                          9319   0.040884  7.043840
# 1222                         32788   0.003324  7.896917
# 1223                         32788   0.036904  7.896917
# 1224                          4548   0.002639  7.992970
#
# [1225 rows x 8 columns]

# %%
plt.hist(ratio,range=[7.5,8])
# Out:
# (array([  0.,  30.,   0.,   0.,   5.,   0.,  59.,  57.,  80., 645.]),
#  array([7.5 , 7.55, 7.6 , 7.65, 7.7 , 7.75, 7.8 , 7.85, 7.9 , 7.95, 8.  ]),
#  <BarContainer object of 10 artists>)

# %%
ratio.max()
# Out:
# np.float64(8.0)

# %%
ratio.min()
# Out:
# np.float64(6.0)

# %%
ratio.value_counts().sort_index(ascending=False)
# Out:
# 8.000000    316
# 7.998877     37
# 7.997251     18
# 7.996874     43
# 7.996564     47
# 7.996390     23
# 7.994922     12
# 7.993009     21
# 7.992970      1
# 7.992916     16
# 7.989877      9
# 7.989130     40
# 7.967593      7
# 7.965517     42
# 7.964652     13
# 7.931142     26
# 7.929661     20
# 7.921600     34
# 7.899021     17
# 7.897683     14
# 7.896917      2
# 7.859766     24
# 7.841981     49
# 7.806061     10
# 7.714286      5
# 7.559509     30
# 7.043840      3
# 6.000000     15
# Name: count, dtype: int64

# %%
# Create the value_counts series
counts = ratio.value_counts()

# Filter the index and sum the values
total_sum = counts[(counts.index >= 7.9) & (counts.index <= 8.0)].sum()

print(total_sum)
# Out:
# 725

# %%
noisy_clusters = [0,3,4,7,21,27,34,45,46] #filter out the noisy clusters 
filtered_df = contact_df[(~contact_df['cluster 1'].isin(noisy_clusters)) & (~contact_df['cluster 2'].isin(noisy_clusters))] #remove self interaction and noise 
filtered_df['ratio'] = filtered_df['total cluster 1 interactions']/filtered_df['total cluster 1']
filtered_df
# Out:
# /tmp/ipykernel_2490696/956512842.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ratio'] = filtered_df['total cluster 1 interactions']/filtered_df['total cluster 1']
#       cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 49            1          2              0                5              291
# 52            1          5              0                5               12
# 53            1          6              0                5             2239
# 55            1          8              0                5                0
# 56            1          9              0                5              184
# ...         ...        ...            ...              ...              ...
# 1213         44         48              0               21              569
# 1214         44         49              0               21             6993
# 1222         47         48            109             4152              569
# 1223         47         49           1210             4152             6993
# 1224         48         49             12              569             6993
#
#       total cluster 1 interactions  frequency     ratio
# 49                              40   0.000000  8.000000
# 52                              40   0.000000  8.000000
# 53                              40   0.000000  8.000000
# 55                              40   0.000000  8.000000
# 56                              40   0.000000  8.000000
# ...                            ...        ...       ...
# 1213                           162   0.000000  7.714286
# 1214                           162   0.000000  7.714286
# 1222                         32788   0.003324  7.896917
# 1223                         32788   0.036904  7.896917
# 1224                          4548   0.002639  7.992970
#
# [820 rows x 8 columns]

# %%
filtered_df[filtered_df['ratio']<=7.6]
# Out:
#      cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 760         19         20              0              815                2
# 762         19         22              0              815                4
# 763         19         23              6              815              639
# 764         19         24              0              815                0
# 765         19         25              0              815             1797
# 766         19         26            156              815              277
# 768         19         28              0              815             3147
# 769         19         29            112              815             1180
# 770         19         30              0              815             1477
# 771         19         31              0              815             1455
# 772         19         32              2              815             2961
# 773         19         33              5              815             4094
# 775         19         35              0              815              518
# 776         19         36           1853              815             4781
# 777         19         37              3              815             5711
# 778         19         38             13              815               53
# 779         19         39             54              815              330
# 780         19         40              0              815             1877
# 781         19         41            125              815              397
# 782         19         42              0              815              216
# 783         19         43              0              815                2
# 784         19         44             14              815               21
# 787         19         47             83              815             4152
# 788         19         48              1              815              569
# 789         19         49              8              815             6993
#
#      total cluster 1 interactions  frequency     ratio
# 760                          6161   0.000000  7.559509
# 762                          6161   0.000000  7.559509
# 763                          6161   0.000974  7.559509
# 764                          6161   0.000000  7.559509
# 765                          6161   0.000000  7.559509
# 766                          6161   0.025321  7.559509
# 768                          6161   0.000000  7.559509
# 769                          6161   0.018179  7.559509
# 770                          6161   0.000000  7.559509
# 771                          6161   0.000000  7.559509
# 772                          6161   0.000325  7.559509
# 773                          6161   0.000812  7.559509
# 775                          6161   0.000000  7.559509
# 776                          6161   0.300763  7.559509
# 777                          6161   0.000487  7.559509
# 778                          6161   0.002110  7.559509
# 779                          6161   0.008765  7.559509
# 780                          6161   0.000000  7.559509
# 781                          6161   0.020289  7.559509
# 782                          6161   0.000000  7.559509
# 783                          6161   0.000000  7.559509
# 784                          6161   0.002272  7.559509
# 787                          6161   0.013472  7.559509
# 788                          6161   0.000162  7.559509
# 789                          6161   0.001298  7.559509

# %%
filtered_df[filtered_df['ratio'].isna()]
# Out:
#      cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 364          8          9              0                0              184
# 365          8         10              0                0                0
# 366          8         11              0                0                0
# 367          8         12              0                0             6235
# 368          8         13              0                0                0
# ..         ...        ...            ...              ...              ...
# 918         24         43              0                0                2
# 919         24         44              0                0               21
# 922         24         47              0                0             4152
# 923         24         48              0                0              569
# 924         24         49              0                0             6993
#
#      total cluster 1 interactions  frequency  ratio
# 364                             0        0.0    NaN
# 365                             0        0.0    NaN
# 366                             0        0.0    NaN
# 367                             0        0.0    NaN
# 368                             0        0.0    NaN
# ..                            ...        ...    ...
# 918                             0        0.0    NaN
# 919                             0        0.0    NaN
# 922                             0        0.0    NaN
# 923                             0        0.0    NaN
# 924                             0        0.0    NaN
#
# [185 rows x 8 columns]

# %%
filtered_df.shape
# Out:
# (820, 8)

# %%
new_ratio = filtered_df['total cluster 1 interactions']/filtered_df['total cluster 1']
plt.hist(new_ratio,range=[7.5,8])
# Out:
# (array([  0.,  25.,   0.,   0.,   3.,   0.,   8.,  48.,  68., 483.]),
#  array([7.5 , 7.55, 7.6 , 7.65, 7.7 , 7.75, 7.8 , 7.85, 7.9 , 7.95, 8.  ]),
#  <BarContainer object of 10 artists>)

# %%
new_ratio.value_counts().sort_index(ascending=False)
# Out:
# 8.000000    241
# 7.998877     32
# 7.997251     15
# 7.996874     37
# 7.996564     39
# 7.996390     19
# 7.994922     10
# 7.993009     18
# 7.992970      1
# 7.992916     13
# 7.989877      7
# 7.989130     35
# 7.967593      5
# 7.964652     11
# 7.931142     22
# 7.929661     17
# 7.921600     29
# 7.899021     14
# 7.897683     12
# 7.896917      2
# 7.859766     20
# 7.806061      8
# 7.714286      3
# 7.559509     25
# Name: count, dtype: int64

# %%
(new_ratio>=7.9).sum()
# Out:
# np.int64(551)

# %%
(new_ratio<7.9).sum()
# Out:
# np.int64(84)

# %%
new_ratio.isna().sum()
# Out:
# np.int64(185)

# %%
new_ratio.shape
# Out:
# (820,)

# %%
filtered_df = contact_df[contact_df['contact count']>contact_df['total cluster 1']]
filtered_df.shape
# Out:
# (28, 7)

# %%
filtered_df
# Out:
#       cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 59            1         12             23                5             6235
# 83            1         36              9                5             4781
# 106           2         12            564              291             6235
# 130           2         36            535              291             4781
# 265           5         36             44               12             4781
# 276           5         47             13               12             4152
# 326           7         12             70               29             6235
# 333           7         19             62               29              815
# 350           7         36             48               29             4781
# 421           9         26            233              184              277
# 431           9         36            383              184             4781
# 545          12         36           7805             6235             4781
# 639          15         25            751              625             1797
# 683          16         36           2383             1126             4781
# 715          17         36            357               94             4781
# 746          18         36             32               11             4781
# 776          19         36           1853              815             4781
# 844          21         47              9                2             4152
# 857          22         33              5                4             4094
# 872          22         48              7                4              569
# 882          23         32            692              639             2961
# 958          26         36            765              277             4781
# 1002         28         37           4785             3147             5711
# 1014         28         49           3321             3147             6993
# 1059         31         37           2009             1455             5711
# 1092         33         37           4365             4094             5711
# 1121         35         37            739              518             5711
# 1188         40         49           2044             1877             6993
#
#       total cluster 1 interactions  frequency
# 59                              40   0.575000
# 83                              40   0.225000
# 106                           2327   0.242372
# 130                           2327   0.229910
# 265                             96   0.458333
# 276                             96   0.135417
# 326                            231   0.303030
# 333                            231   0.268398
# 350                            231   0.207792
# 421                           1470   0.158503
# 431                           1470   0.260544
# 545                          49873   0.156498
# 639                           4951   0.151687
# 683                           9008   0.264543
# 715                            752   0.474734
# 746                             88   0.363636
# 776                           6161   0.300763
# 844                             16   0.562500
# 857                             32   0.156250
# 872                             32   0.218750
# 882                           5068   0.136543
# 958                           2215   0.345372
# 1002                         25154   0.190228
# 1014                         25154   0.132027
# 1059                         11636   0.172654
# 1092                         32723   0.133392
# 1121                          4091   0.180640
# 1188                         14997   0.136294

# %%
test_df = sample_df[sample_df['label']==1]
test_df
# Out:
#        label      X      Y
# number
# 47530      1  59648  52736
# 53524      1  65280  47104
# 53798      1  65536  48384
# 57737      1  69632  49152
# 62156      1  77312  41984

# %%
stride = 256
offsets = [
    (stride, 0), (-stride, 0), (0, stride), (0, -stride),
    (stride, stride), (-stride, -stride), (stride, -stride), (-stride, stride)
]

# Create a list to store all neighbor information
neighbor_data = []

# Iterate through the DataFrame rows
for index, row in test_df.iterrows():
    center_x, center_y = row['X'], row['Y']
    
    # Calculate each neighbor based on the offsets
    for dx, dy in offsets:
        neighbor_x = center_x + dx
        neighbor_y = center_y + dy
        
        neighbor_data.append({
            'original_index': index,
            'neighbor_x': neighbor_x,
            'neighbor_y': neighbor_y
        })
neighbors_df = pd.DataFrame(neighbor_data)

# %%
# Create coordinate pairs as tuples
neighbor_tuples = list(zip(neighbors_df.neighbor_x, neighbors_df.neighbor_y))
sample_tuples = list(zip(sample_df.X, sample_df.Y))

# Filter based on membership
neighbor_df = sample_df[pd.Series(sample_tuples).isin(neighbor_tuples).values]
neighbor_df
# Out:
#        label      X      Y
# number
# 47259     12  59392  52480
# 47260     12  59392  52736
# 47261     12  59392  52992
# 47529     12  59648  52480
# 47531     12  59648  52992
# 47800     16  59904  52480
# 47801     16  59904  52736
# 47802     12  59904  52992
# 53252     12  65024  46848
# 53253     12  65024  47104
# 53254     12  65024  47360
# 53523     12  65280  46848
# 53525     16  65280  47360
# 53528     36  65280  48128
# 53529     36  65280  48384
# 53530     41  65280  48640
# 53792     12  65536  46848
# 53793     36  65536  47104
# 53794     36  65536  47360
# 53797     36  65536  48128
# 53799     16  65536  48640
# 54064     12  65792  48128
# 54065     12  65792  48384
# 54066     41  65792  48640
# 57513     12  69376  48896
# 57514     12  69376  49152
# 57515     36  69376  49408
# 57736     36  69632  48896
# 57738     41  69632  49408
# 57957     12  69888  48896
# 57958     12  69888  49152
# 57959     36  69888  49408
# 62115     36  77056  41728
# 62116     19  77056  41984
# 62117     12  77056  42240
# 62155     12  77312  41728
# 62157     12  77312  42240
# 62193     12  77568  41728
# 62194     12  77568  41984
# 62195     12  77568  42240

# %%
result_df = pd.concat([test_df, neighbor_df])
result_df.sort_values(by=['X'])
# Out:
#        label      X      Y
# number
# 47260     12  59392  52736
# 47261     12  59392  52992
# 47259     12  59392  52480
# 47530      1  59648  52736
# 47531     12  59648  52992
# 47529     12  59648  52480
# 47801     16  59904  52736
# 47800     16  59904  52480
# 47802     12  59904  52992
# 53252     12  65024  46848
# 53253     12  65024  47104
# 53254     12  65024  47360
# 53524      1  65280  47104
# 53528     36  65280  48128
# 53525     16  65280  47360
# 53523     12  65280  46848
# 53530     41  65280  48640
# 53529     36  65280  48384
# 53798      1  65536  48384
# 53799     16  65536  48640
# 53797     36  65536  48128
# 53792     12  65536  46848
# 53793     36  65536  47104
# 53794     36  65536  47360
# 54066     41  65792  48640
# 54065     12  65792  48384
# 54064     12  65792  48128
# 57513     12  69376  48896
# 57514     12  69376  49152
# 57515     36  69376  49408
# 57737      1  69632  49152
# 57736     36  69632  48896
# 57738     41  69632  49408
# 57959     36  69888  49408
# 57957     12  69888  48896
# 57958     12  69888  49152
# 62116     19  77056  41984
# 62115     36  77056  41728
# 62117     12  77056  42240
# 62156      1  77312  41984
# 62155     12  77312  41728
# 62157     12  77312  42240
# 62193     12  77568  41728
# 62194     12  77568  41984
# 62195     12  77568  42240

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# 1. Get the base tab20 colormap
tab20 = cm.get_cmap('tab20')

# 2. Get unique categories from your plot_df
unique_cats = sorted(result_df['label'].unique())

# 3. Create a color dictionary mapping each category to its tab20 color with overrides
palette = {}
for cat in unique_cats:
    # Default: Use tab20 colors (cycling by modulo 20)
    color = tab20(cat % 20)
    
    # Apply your specific overrides
    if cat == 41:
        color = 'black'
    elif cat == 16:
        color = 'red'
        
    palette[cat] = color

# 4. Plotting (e.g., using a loop or passing the palette to Seaborn)
# If using a loop to ensure unique legend entries:
fig, ax = plt.subplots(figsize=(10, 6))

for cat in unique_cats:
    subset = result_df[result_df['label'] == cat]
    ax.scatter(subset['X'], subset['Y'], label=cat, color=palette[cat])

# 5. Clean up the legend to only show unique categories
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(by_label.values(), by_label.keys(), title="Unique Categories", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Cluster 5, 36 and Cluster 5, 47 Interactions")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_559995/3491683610.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   tab20 = cm.get_cmap('tab20')

# %%
result_df.value_counts('label')
# Out:
# label
# 12    23
# 36     9
# 1      5
# 16     4
# 41     3
# 19     1
# 6      0
# 0      0
# 2      0
# 3      0
# 9      0
# 8      0
# 11     0
# 10     0
# 13     0
# 7      0
# 4      0
# 5      0
# 17     0
# 15     0
# 14     0
# 18     0
# 22     0
# 23     0
# 20     0
# 21     0
# 26     0
# 27     0
# 28     0
# 29     0
# 30     0
# 31     0
# 24     0
# 25     0
# 33     0
# 32     0
# 35     0
# 34     0
# 37     0
# 38     0
# 39     0
# 40     0
# 42     0
# 43     0
# 44     0
# 45     0
# 46     0
# 47     0
# 48     0
# 49     0
# Name: count, dtype: int64

# %%
contact_df[contact_df['cluster 1']==1]
# Out:
#     cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 49          1          2              0                5              291
# 50          1          3              0                5                0
# 51          1          4              0                5                0
# 52          1          5              0                5               12
# 53          1          6              0                5             2239
# 54          1          7              0                5               29
# 55          1          8              0                5                0
# 56          1          9              0                5              184
# 57          1         10              0                5                0
# 58          1         11              0                5                0
# 59          1         12             23                5             6235
# 60          1         13              0                5                0
# 61          1         14              0                5                0
# 62          1         15              0                5              625
# 63          1         16              4                5             1126
# 64          1         17              0                5               94
# 65          1         18              0                5               11
# 66          1         19              1                5              815
# 67          1         20              0                5                2
# 68          1         21              0                5                2
# 69          1         22              0                5                4
# 70          1         23              0                5              639
# 71          1         24              0                5                0
# 72          1         25              0                5             1797
# 73          1         26              0                5              277
# 74          1         27              0                5                0
# 75          1         28              0                5             3147
# 76          1         29              0                5             1180
# 77          1         30              0                5             1477
# 78          1         31              0                5             1455
# 79          1         32              0                5             2961
# 80          1         33              0                5             4094
# 81          1         34              0                5                2
# 82          1         35              0                5              518
# 83          1         36              9                5             4781
# 84          1         37              0                5             5711
# 85          1         38              0                5               53
# 86          1         39              0                5              330
# 87          1         40              0                5             1877
# 88          1         41              3                5              397
# 89          1         42              0                5              216
# 90          1         43              0                5                2
# 91          1         44              0                5               21
# 92          1         45              0                5                0
# 93          1         46              0                5             1323
# 94          1         47              0                5             4152
# 95          1         48              0                5              569
# 96          1         49              0                5             6993
#
#     total cluster 1 interactions  frequency
# 49                            40      0.000
# 50                            40      0.000
# 51                            40      0.000
# 52                            40      0.000
# 53                            40      0.000
# 54                            40      0.000
# 55                            40      0.000
# 56                            40      0.000
# 57                            40      0.000
# 58                            40      0.000
# 59                            40      0.575
# 60                            40      0.000
# 61                            40      0.000
# 62                            40      0.000
# 63                            40      0.100
# 64                            40      0.000
# 65                            40      0.000
# 66                            40      0.025
# 67                            40      0.000
# 68                            40      0.000
# 69                            40      0.000
# 70                            40      0.000
# 71                            40      0.000
# 72                            40      0.000
# 73                            40      0.000
# 74                            40      0.000
# 75                            40      0.000
# 76                            40      0.000
# 77                            40      0.000
# 78                            40      0.000
# 79                            40      0.000
# 80                            40      0.000
# 81                            40      0.000
# 82                            40      0.000
# 83                            40      0.225
# 84                            40      0.000
# 85                            40      0.000
# 86                            40      0.000
# 87                            40      0.000
# 88                            40      0.075
# 89                            40      0.000
# 90                            40      0.000
# 91                            40      0.000
# 92                            40      0.000
# 93                            40      0.000
# 94                            40      0.000
# 95                            40      0.000
# 96                            40      0.000

# %%
cluster_tuples_1 = list(zip(filtered_df['cluster 1'], filtered_df['cluster 2']))

# %%
new_filtered_df = contact_df[contact_df['contact count']>contact_df['total cluster 2']]
new_filtered_df.shape
# Out:
# (24, 7)

# %%
new_filtered_df
# Out:
#       cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 14            0         15           3166             6765              625
# 24            0         25           5208             6765             1797
# 33            0         34             10             6765                2
# 294           6         22              7             2239                4
# 302           6         30           1606             2239             1477
# 315           6         43              6             2239                2
# 320           6         48            865             2239              569
# 433           9         38             98              184               53
# 525          12         16           2333             6235             1126
# 527          12         18             36             6235               11
# 528          12         19           1047             6235              815
# 529          12         20             11             6235                2
# 535          12         26            445             6235              277
# 545          12         36           7805             6235             4781
# 550          12         41           1529             6235              397
# 553          12         44             36             6235               21
# 669          16         22              6             1126                4
# 1052         30         48            949             1477              569
# 1057         31         35            589             1455              518
# 1097         33         42            495             4094              216
# 1135         36         38            141             4781               53
# 1138         36         41            806             4781              397
# 1141         36         44             42             4781               21
# 1149         37         40           3646             5711             1877
#
#       total cluster 1 interactions  frequency
# 14                           35018   0.090411
# 24                           35018   0.148724
# 33                           35018   0.000286
# 294                          23290   0.000301
# 302                          23290   0.068957
# 315                          23290   0.000258
# 320                          23290   0.037140
# 433                           1924   0.050936
# 525                          28466   0.081957
# 527                          28466   0.001265
# 528                          28466   0.036781
# 529                          28466   0.000386
# 535                          28466   0.015633
# 545                          28466   0.274187
# 550                          28466   0.053713
# 553                          28466   0.001265
# 669                          11424   0.000525
# 1052                         10212   0.092930
# 1057                         12656   0.046539
# 1097                         33934   0.014587
# 1135                         35074   0.004020
# 1138                         35074   0.022980
# 1141                         35074   0.001197
# 1149                         42754   0.085279

# %%
cluster_tuples_2 = list(zip(new_filtered_df['cluster 1'], new_filtered_df['cluster 2']))
combined_set = set(cluster_tuples_1).union(cluster_tuples_2)
len(combined_set)
# Out:
# 51

# %%
from itertools import combinations

# 1. Setup Parameters
cancer_types = ['coad', 'esca', 'paad', 'stad', 'read']
stride = 256
offsets = [(stride, 0), (-stride, 0), (0, stride), (0, -stride),
           (stride, stride), (-stride, -stride), (stride, -stride), (-stride, stride)]

all_results = []
num_clusters = 50

# 2. Outer Progress Bar: Cancer Types
pbar_ct = tqdm(cancer_types, desc="Overall Progress")

for ct in pbar_ct:
    # Slice the main dataframe for the current cancer type
    ct_data = labelled_data.loc[ct]
    slide_ids = ct_data.index.get_level_values('tcga_id').unique()
    
    # Inner Progress Bar: Slides within the current Cancer Type
    pbar_slides = tqdm(slide_ids, desc=f"Processing {ct.upper()}", leave=False)
    
    for sid in pbar_slides:
        # Isolate the specific slide coordinates and labels
        slide_df = ct_data.loc[sid]
        
        # Fast lookup map using a dictionary for O(1) spatial queries
        coord_map = dict(zip(zip(slide_df['X'], slide_df['Y']), slide_df['label']))
        
        # Initialize an adjacency matrix for this specific slide
        contact_matrix = np.zeros((num_clusters, num_clusters), dtype=int)
        
        # 3. Spatial Iteration: Check 8 neighbors for every point
        for (x, y), l_center in coord_map.items():
            for dx, dy in offsets:
                neighbor = (x + dx, y + dy)
                
                # Check if neighbor exists
                if neighbor in coord_map:
                    l_neigh = coord_map[neighbor]
                    contact_matrix[l_center, l_neigh] += 1
        
        # 4. Reference the pre-computed counts for this specific slide
        counts_for_slide = label_counts.loc[sid]
        
        # 5. Calculate Pairwise Metrics
        for c1, c2 in combinations(range(num_clusters), 2):
            contact_count = contact_matrix[c1, c2]
            
            if contact_count > 0:
                # We now use the total interactions as the denominator
                # total_interactions_c1 must be calculated for each c1
                c1_total_neighbors = contact_matrix[c1, :].sum()
                
                all_results.append({
                    'cancer_type': ct,
                    'tcga_id': sid,
                    'cluster 1': c1,
                    'cluster 2': c2,
                    'contact count': contact_count,
                    'total cluster 1': slide_df['label'].value_counts()[c1],
                    'total cluster 2': slide_df['label'].value_counts()[c2], 
                    'total_c1_interactions': c1_total_neighbors,
                    'frequency': contact_count / c1_total_neighbors if c1_total_neighbors > 0 else 0
                })
# 6. Final Data Consolidation
final_contact_df = pd.DataFrame(all_results)
# Out:
# Overall Progress:   0%|          | 0/5 [00:00<?, ?it/s]
# Processing COAD:   0%|          | 0/396 [00:00<?, ?it/s]
# Processing ESCA:   0%|          | 0/150 [00:00<?, ?it/s]
# Processing PAAD:   0%|          | 0/209 [00:00<?, ?it/s]
# Processing STAD:   0%|          | 0/398 [00:00<?, ?it/s]
# Processing READ:   0%|          | 0/158 [00:00<?, ?it/s]

# %%
final_contact_df
# Out:
#        cancer_type                                            tcga_id  \
# 0             coad  TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-945...
# 1             coad  TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-945...
# 2             coad  TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-945...
# 3             coad  TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd8...
# 4             coad  TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd8...
# ...            ...                                                ...
# 279948        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279949        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279950        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279951        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279952        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
#
#         cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 0               3          4           8825             4126             3722
# 1               3         34            543             4126              129
# 2               4         34            108             3722              129
# 3               3          4          16012             7085            13341
# 4               3         13              8             7085                1
# ...           ...        ...            ...              ...              ...
# 279948         44         46             25              571              337
# 279949         44         49              2              571             3080
# 279950         46         49             30              337             3080
# 279951         47         49              3               10             3080
# 279952         48         49              4               13             3080
#
#         total_c1_interactions  frequency
# 0                       30362   0.290659
# 1                       30362   0.017884
# 2                       29409   0.003672
# 3                       54786   0.292264
# 4                       54786   0.000146
# ...                       ...        ...
# 279948                   4512   0.005541
# 279949                   4512   0.000443
# 279950                   2482   0.012087
# 279951                     60   0.050000
# 279952                    104   0.038462
#
# [279953 rows x 9 columns]

# %%
final_contact_df.to_pickle('pkl/cluster_50_pairwise_slide_04_06_26.pkl')

# %%
# 1. Group by cancer type and cluster pair to get contact counts
# We also include 'total cluster 1' and 'total_c1_interactions' in the mean or sum
# depending on how they were calculated per slide.
summary_df = final_contact_df.groupby(['cancer_type', 'cluster 1', 'cluster 2']).agg({
    'contact count': 'sum',
    'total cluster 1': 'sum',
    'total_c1_interactions': 'sum'
}).reset_index()

# 2. Recalculate Frequency
# Frequency = (Total Contacts between C1 and C2) / (Total Interactions C1 had overall)
summary_df['frequency'] = summary_df['contact count'] / summary_df['total_c1_interactions']

# 3. Optional: Calculate the "Global Ratio" to see if it approaches 8
# summary_df['global_ratio'] = summary_df['total_c1_interactions'] / summary_df['total cluster 1']

summary_df = summary_df.sort_values(['cancer_type', 'cluster 1', 'cluster 2'])

# %%
summary_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total cluster 1  \
# 0           coad          0          1             77           239810
# 1           coad          0          2           3480           612543
# 2           coad          0          3             58            48398
# 3           coad          0          4             16             1003
# 4           coad          0          5            554           282791
# ...          ...        ...        ...            ...              ...
# 5814        stad         46         48          23826           326760
# 5815        stad         46         49          27181           452970
# 5816        stad         47         48          12384            85161
# 5817        stad         47         49           5744           143759
# 5818        stad         48         49           8495           327115
#
#       total_c1_interactions  frequency
# 0                   1871860   0.000041
# 1                   4738758   0.000734
# 2                    370757   0.000156
# 3                      6726   0.002379
# 4                   2190947   0.000253
# ...                     ...        ...
# 5814                2409259   0.009889
# 5815                3323591   0.008178
# 5816                 647334   0.019131
# 5817                1106262   0.005192
# 5818                2602832   0.003264
#
# [5819 rows x 7 columns]

# %%
summary_df.to_pickle('pkl/cluster_50_pairwise_summary_04_06_26.pkl')

# %%
summary_df = pd.read_pickle('pkl/cluster_50_pairwise_summary_04_06_26.pkl')

# %%
noisy_clusters = [0,3,4,7,21,27,34,45,46] #filter out the noisy clusters 
filtered_summary_df = summary_df[(~summary_df['cluster 1'].isin(noisy_clusters)) & (~summary_df['cluster 2'].isin(noisy_clusters))] #remove self interaction and noise 
filtered_summary_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total cluster 1  \
# 49          coad          1          2           3739            43957
# 52          coad          1          5           2228            36195
# 53          coad          1          6           4471            35829
# 55          coad          1          8           1612            19618
# 56          coad          1          9          33960            40767
# ...          ...        ...        ...            ...              ...
# 5807        stad         44         48           3816            63961
# 5808        stad         44         49             39            17637
# 5816        stad         47         48          12384            85161
# 5817        stad         47         49           5744           143759
# 5818        stad         48         49           8495           327115
#
#       total_c1_interactions  frequency
# 49                   351321   0.010643
# 52                   289237   0.007703
# 53                   286306   0.015616
# 55                   156871   0.010276
# 56                   325839   0.104223
# ...                     ...        ...
# 5807                 505297   0.007552
# 5808                 139913   0.000279
# 5816                 647334   0.019131
# 5817                1106262   0.005192
# 5818                2602832   0.003264
#
# [3975 rows x 7 columns]

# %%
filtered_summary_df['cancer_type'].value_counts()
# Out:
# cancer_type
# stad    818
# paad    806
# coad    804
# esca    787
# read    760
# Name: count, dtype: int64

# %%
filtered_summary_df['global_ratio'] = filtered_summary_df['total_c1_interactions']/filtered_summary_df['total cluster 1']
# Out:
# /tmp/ipykernel_1481881/1906798748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_summary_df['global_ratio'] = filtered_summary_df['total_c1_interactions']/filtered_summary_df['total cluster 1']

# %%
plt.hist(filtered_summary_df['global_ratio'],range=[7.5,8]) 
plt.title('Distribution of Cluster Ratios') 
plt.xlabel('Ratio of total Ci interactions to total Ci') 
plt.ylabel('Counts') 
plt.savefig('png/ratio_histogram.png')

# %%
global_ratio = filtered_summary_df['global_ratio']
(global_ratio>7.9).sum()
# Out:
# np.int64(3438)

# %%
(global_ratio>7.95).sum()
# Out:
# np.int64(2844)

# %%
((filtered_summary_df['global_ratio'] > 7.5) & (filtered_summary_df['global_ratio'] < 7.9)).sum()
# Out:
# np.int64(505)

# %%
filtered_summary_df['global_ratio'].value_counts().sort_index(ascending=False)
# Out:
# global_ratio
# 8.000000    78
# 7.999643     1
# 7.999569     1
# 7.999549     1
# 7.999294     1
#             ..
# 6.428571     1
# 6.250000     1
# 5.888889     1
# 5.857143     1
# 5.500000     1
# Name: count, Length: 3877, dtype: int64

# %%
final_ratio = final_contact_df['total_c1_interactions']/final_contact_df['total cluster 1']
final_contact_df['ratio'] = final_ratio 
final_contact_df
# Out:
#        cancer_type                                            tcga_id  \
# 0             coad  TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-945...
# 1             coad  TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-945...
# 2             coad  TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-945...
# 3             coad  TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd8...
# 4             coad  TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd8...
# ...            ...                                                ...
# 279948        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279949        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279950        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279951        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279952        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
#
#         cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 0               3          4           8825             4126             3722
# 1               3         34            543             4126              129
# 2               4         34            108             3722              129
# 3               3          4          16012             7085            13341
# 4               3         13              8             7085                1
# ...           ...        ...            ...              ...              ...
# 279948         44         46             25              571              337
# 279949         44         49              2              571             3080
# 279950         46         49             30              337             3080
# 279951         47         49              3               10             3080
# 279952         48         49              4               13             3080
#
#         total_c1_interactions  frequency     ratio
# 0                       30362   0.290659  7.358701
# 1                       30362   0.017884  7.358701
# 2                       29409   0.003672  7.901397
# 3                       54786   0.292264  7.732675
# 4                       54786   0.000146  7.732675
# ...                       ...        ...       ...
# 279948                   4512   0.005541  7.901926
# 279949                   4512   0.000443  7.901926
# 279950                   2482   0.012087  7.364985
# 279951                     60   0.050000  6.000000
# 279952                    104   0.038462  8.000000
#
# [279953 rows x 10 columns]

# %%
noisy_clusters = [0,3,4,7,21,27,34,45,46] #filter out the noisy clusters 
filtered_df = final_contact_df[(~final_contact_df['cluster 1'].isin(noisy_clusters)) & (~final_contact_df['cluster 2'].isin(noisy_clusters))] #remove self interaction and noise 
filtered_df
# Out:
#        cancer_type                                            tcga_id  \
# 13            coad  TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd8...
# 38            coad  TCGA-D5-6535-01Z-00-DX1.0d7485ff-cf98-4c86-8a6...
# 39            coad  TCGA-D5-6535-01Z-00-DX1.0d7485ff-cf98-4c86-8a6...
# 40            coad  TCGA-D5-6535-01Z-00-DX1.0d7485ff-cf98-4c86-8a6...
# 41            coad  TCGA-D5-6535-01Z-00-DX1.0d7485ff-cf98-4c86-8a6...
# ...            ...                                                ...
# 279946        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279947        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279949        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279951        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
# 279952        read  TCGA-F5-6861-01Z-00-DX1.011B771B-F52E-412E-935...
#
#         cluster 1  cluster 2  contact count  total cluster 1  total cluster 2  \
# 13             17         36              1                1                1
# 38              1          2              1               20             2098
# 39              1          8              3               20              210
# 40              1          9             49               20             6183
# 41              1         11              1               20               85
# ...           ...        ...            ...              ...              ...
# 279946         42         48              1              136               13
# 279947         42         49            182              136             3080
# 279949         44         49              2              571             3080
# 279951         47         49              3               10             3080
# 279952         48         49              4               13             3080
#
#         total_c1_interactions  frequency     ratio
# 13                          8   0.125000  8.000000
# 38                        160   0.006250  8.000000
# 39                        160   0.018750  8.000000
# 40                        160   0.306250  8.000000
# 41                        160   0.006250  8.000000
# ...                       ...        ...       ...
# 279946                   1076   0.000929  7.911765
# 279947                   1076   0.169145  7.911765
# 279949                   4512   0.000443  7.901926
# 279951                     60   0.050000  6.000000
# 279952                    104   0.038462  8.000000
#
# [205974 rows x 10 columns]

# %%
filtered_ratio.shape
# Out:
# (205974,)

# %%
filtered_ratio = filtered_df['ratio']

# %%
plt.hist(filtered_df['ratio'],range=[7.5,8])
plt.xlabel('Ratio of total C1 interactions to total C1') 
plt.ylabel('Counts') 
plt.title('Distribution of Ratios Across C1, C2 Pairs in All Slides')
# Out:
# Text(0.5, 1.0, 'Distribution of Ratios Across C1, C2 Pairs in All Slides')

# %%
(filtered_ratio==8).sum()
# Out:
# np.int64(50017)

# %%
(filtered_ratio>7.9).sum()
# Out:
# np.int64(158343)

# %%
(filtered_ratio<7.5).sum()
# Out:
# np.int64(14583)

# %%
(filtered_ratio>7.5 and filtered_ratio<7.9).sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1638789/758131926.py in ?()
# ----> 1 (filtered_ratio>7.5 and filtered_ratio<7.9).sum()
#
# /home/vshir/ENTER/envs/r_env/lib/python3.13/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
filtered_ratio.value_counts().sort_index(ascending=False)
# Out:
# ratio
# 8.000000    50017
# 7.999939       16
# 7.999907       25
# 7.999902        8
# 7.999887       12
#             ...
# 4.125000        1
# 4.000000       63
# 3.500000        2
# 3.333333        1
# 3.000000        3
# Name: count, Length: 12547, dtype: int64

# %%
# 1. Define the boolean condition for 'excess'
is_excess = (final_contact_df['contact count'] > final_contact_df['total cluster 1']) | \
            (final_contact_df['contact count'] > final_contact_df['total cluster 2'])

# 2. Add the boolean result as a temporary column
final_contact_df['is_excess'] = is_excess

# 3. Group by slide and calculate sum (excess) and count (unique rows)
# We use 'agg' to perform multiple calculations at once
diagnostic_df = final_contact_df.groupby(['tcga_id', 'cancer_type'])['is_excess'].agg(
    excess_counts='sum',
    unique_counts='count'
).reset_index()

# 4. Calculate the frequency using the new columns
diagnostic_df['excess_frequency'] = diagnostic_df['excess_counts'] / diagnostic_df['unique_counts']

# 5. Clean up the original dataframe
final_contact_df.drop(columns=['is_excess'], inplace=True)

diagnostic_df
# Out:
#                                                 tcga_id cancer_type  \
# 0     TCGA-2H-A9GF-01Z-00-DX1.FA1016AF-3FE3-45DC-A77...        esca
# 1     TCGA-2H-A9GG-01Z-00-DX1.0C979026-128C-4124-96C...        esca
# 2     TCGA-2H-A9GH-01Z-00-DX1.B2BF80D6-D348-4C5F-A20...        esca
# 3     TCGA-2H-A9GI-01Z-00-DX1.02AA1DD3-2082-4B82-B39...        esca
# 4     TCGA-2H-A9GJ-01Z-00-DX1.F6CC7FC9-85DB-4791-B36...        esca
# ...                                                 ...         ...
# 1306  TCGA-Z6-A9VB-01Z-00-DX1.D35A32ED-DFEE-4070-954...        esca
# 1307  TCGA-Z6-AAPN-01Z-00-DX1.345F7431-CD48-40DB-89D...        esca
# 1308  TCGA-ZA-A8F6-01Z-00-DX1.89510833-5BC8-4983-817...        stad
# 1309  TCGA-ZQ-A9CR-01Z-00-DX1.C9AC9991-7054-4068-A7A...        stad
# 1310  TCGA-ZR-A9CJ-01Z-00-DX1.4A1AE826-FB78-4DD3-881...        esca
#
#       excess_counts  unique_counts  excess_frequency
# 0                64            507          0.126233
# 1                67            340          0.197059
# 2                82            352          0.232955
# 3                54            278          0.194245
# 4                59            229          0.257642
# ...             ...            ...               ...
# 1306             52            189          0.275132
# 1307             69            225          0.306667
# 1308             71            303          0.234323
# 1309             46            155          0.296774
# 1310             60            180          0.333333
#
# [1311 rows x 5 columns]

# %%
diagnostic_df['excess_frequency'].hist(edgecolor='white')
plt.xlabel('High Contact Count Frequency')
plt.ylabel('Counts') 
plt.title('Overall Distribution of High Contact Count Frequencies') 
plt.grid(False) 
plt.show()

# %%
diagnostic_df[diagnostic_df['tcga_id']=='TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f2-0dc195a3d7df']
# Out:
#                                                tcga_id cancer_type  \
# 865  TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f...        coad
#
#      excess_counts  unique_counts  excess_frequency
# 865             51            366          0.139344

# %%
import matplotlib.pyplot as plt

# Using the 'by' parameter creates a subplot for each unique value in cancer_type
axes = diagnostic_df.hist(
    column='excess_frequency', 
    by='cancer_type', 
    figsize=(12, 10),    # Adjust size based on number of cancer types
    bins=15,             # Adjust bins for better granularity
    edgecolor='white',   # Better visual separation of bars
    grid=False           # Removes gridlines automatically
)

# 2. Iterate through the array of axes to set labels
for ax in axes.flatten():  # .flatten() makes it easy to loop even if it's a 2D grid
    ax.set_xlabel('High Contact Count Frequency')
    ax.set_ylabel('Counts')
    
    # Optional: Make titles slightly smaller to avoid crowding
    ax.title.set_size(10)
    
# Improve layout to prevent titles from overlapping axes
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 

plt.show()

# %%
# 1. Sum contact counts across all slides for each cancer_type and pair
aggregated_df = final_contact_df.groupby(['cancer_type', 'cluster 1', 'cluster 2'])['contact count'].sum().reset_index()

# 2. Calculate the GLOBAL total interactions for Cluster 1 within each cancer type
# First, get totals where it appears as cluster 1
c1_sums = aggregated_df.groupby(['cancer_type', 'cluster 1'])['contact count'].sum().reset_index()
c1_sums.columns = ['cancer_type', 'cluster 1', 'total c1 interactions']

# 3. Merge this global total back into your summary dataframe
# This ensures every row with (cancer_type, cluster 1) has the exact same denominator
summary_df = aggregated_df.merge(c1_sums, on=['cancer_type', 'cluster 1'])

# 4. Recompute frequency based on global interaction total
summary_df['frequency'] = summary_df['contact count'] / summary_df['total c1 interactions']
summary_df = summary_df.sort_values(['cancer_type', 'cluster 1', 'cluster 2'])

# %%
summary_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total c1 interactions  \
# 0           coad          0          1             77                2385825
# 1           coad          0          2           3480                2385825
# 2           coad          0          3             58                2385825
# 3           coad          0          4             16                2385825
# 4           coad          0          5            554                2385825
# ...          ...        ...        ...            ...                    ...
# 5814        stad         46         48          23826                 197628
# 5815        stad         46         49          27181                 197628
# 5816        stad         47         48          12384                  18128
# 5817        stad         47         49           5744                  18128
# 5818        stad         48         49           8495                   8495
#
#       frequency
# 0      0.000032
# 1      0.001459
# 2      0.000024
# 3      0.000007
# 4      0.000232
# ...         ...
# 5814   0.120560
# 5815   0.137536
# 5816   0.683142
# 5817   0.316858
# 5818   1.000000
#
# [5819 rows x 6 columns]

# %%
summary_df = pd.read_pickle('pkl/cluster_50_pairwise_summary_03_31_26.pkl')
summary_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total c1 interactions  \
# 1196        coad         48         49           8808                   8808
# 144         coad          3          4        1660282                1906229
# 1194        coad         47         48          25201                  28953
# 1178        coad         43         46            347                    443
# 1088        coad         34         46           1817                   2672
# ...          ...        ...        ...            ...                    ...
# 4762        stad          3         12              1                 359470
# 4781        stad          3         31              1                 359470
# 5032        stad          9         34              3                1495605
# 5051        stad         10         14              1                 566290
# 4626        stad          0         14              1                 810392
#
#       frequency
# 1196   1.000000
# 144    0.870977
# 1194   0.870411
# 1178   0.783296
# 1088   0.680015
# ...         ...
# 4762   0.000003
# 4781   0.000003
# 5032   0.000002
# 5051   0.000002
# 4626   0.000001
#
# [5819 rows x 6 columns]

# %%
summary_df = summary_df.sort_values(['cancer_type', 'frequency'], ascending=[True, False])
summary_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total c1 interactions  \
# 1196        coad         48         49           8808                   8808
# 144         coad          3          4        1660282                1906229
# 1194        coad         47         48          25201                  28953
# 1178        coad         43         46            347                    443
# 1088        coad         34         46           1817                   2672
# ...          ...        ...        ...            ...                    ...
# 4762        stad          3         12              1                 359470
# 4781        stad          3         31              1                 359470
# 5032        stad          9         34              3                1495605
# 5051        stad         10         14              1                 566290
# 4626        stad          0         14              1                 810392
#
#       frequency
# 1196   1.000000
# 144    0.870977
# 1194   0.870411
# 1178   0.783296
# 1088   0.680015
# ...         ...
# 4762   0.000003
# 4781   0.000003
# 5032   0.000002
# 5051   0.000002
# 4626   0.000001
#
# [5819 rows x 6 columns]

# %%
noisy_clusters = [0,3,4,7,21,27,34,45,46] #filter out the noisy clusters 
filtered_df = summary_df[(~summary_df['cluster 1'].isin(noisy_clusters)) & (~summary_df['cluster 2'].isin(noisy_clusters))] #remove self interaction and noise 
filtered_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total c1 interactions  \
# 1196        coad         48         49           8808                   8808
# 1194        coad         47         48          25201                  28953
# 1190        coad         45         49          24934                  36852
# 617         coad         15         25         567481                 889755
# 934         coad         26         36         636528                1004144
# ...          ...        ...        ...            ...                    ...
# 5604        stad         28         44              3                 677711
# 5617        stad         29         37              1                 228061
# 4670        stad          1         10              8                1834005
# 5008        stad          9         10              5                1495605
# 5051        stad         10         14              1                 566290
#
#       frequency
# 1196   1.000000
# 1194   0.870411
# 1190   0.676598
# 617    0.637795
# 934    0.633901
# ...         ...
# 5604   0.000004
# 5617   0.000004
# 4670   0.000004
# 5008   0.000003
# 5051   0.000002
#
# [4166 rows x 6 columns]

# %%
filtered_df_2 = original_df[(~original_df['cluster 1'].isin(noisy_clusters)) & (~original_df['cluster 2'].isin(noisy_clusters))] #remove self interaction and noise 
filtered_df_2
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total c1 interactions  \
# 1196        coad         48         49          17616                  17616
# 1194        coad         47         48          50402                  57906
# 1190        coad         45         49          49868                  73704
# 617         coad         15         25        1134962                1779510
# 934         coad         26         36        1273056                2008288
# ...          ...        ...        ...            ...                    ...
# 5604        stad         28         44              6                1355422
# 5617        stad         29         37              2                 456122
# 4670        stad          1         10             16                3668010
# 5008        stad          9         10             10                2991210
# 5051        stad         10         14              2                1132580
#
#       frequency
# 1196   1.000000
# 1194   0.870411
# 1190   0.676598
# 617    0.637795
# 934    0.633901
# ...         ...
# 5604   0.000004
# 5617   0.000004
# 4670   0.000004
# 5008   0.000003
# 5051   0.000002
#
# [4166 rows x 6 columns]

# %%
final_contact_df.to_pickle('pkl/cluster_50_pairwise_slide_03_31_26.pkl') 
summary_df.to_pickle('pkl/cluster_50_pairwise_summary_03_31_26.pkl')

# %%
original_df = pd.read_pickle('pkl/cluster_50_pairwise_summary_03_04_26.pkl')

# %%
original_df
# Out:
#      cancer_type  cluster 1  cluster 2  contact count  total c1 interactions  \
# 1196        coad         48         49          17616                  17616
# 144         coad          3          4        3320564                3812458
# 1194        coad         47         48          50402                  57906
# 1178        coad         43         46            694                    886
# 1088        coad         34         46           3634                   5344
# ...          ...        ...        ...            ...                    ...
# 4762        stad          3         12              2                 718940
# 4781        stad          3         31              2                 718940
# 5032        stad          9         34              6                2991210
# 5051        stad         10         14              2                1132580
# 4626        stad          0         14              2                1620784
#
#       frequency
# 1196   1.000000
# 144    0.870977
# 1194   0.870411
# 1178   0.783296
# 1088   0.680015
# ...         ...
# 4762   0.000003
# 4781   0.000003
# 5032   0.000002
# 5051   0.000002
# 4626   0.000001
#
# [5819 rows x 6 columns]

# %%
freq_df = filtered_df.set_index(['cluster 1','cluster 2','cancer_type'])['frequency'].unstack().fillna(0)

# %%
freq_df
# Out:
# cancer_type              coad      esca      paad      read      stad
# cluster 1 cluster 2
# 1         2          0.012813  0.013091  0.049265  0.005715  0.013170
#           5          0.007635  0.009590  0.022278  0.001487  0.004077
#           6          0.015321  0.032138  0.031362  0.007885  0.036592
#           8          0.005524  0.005382  0.003146  0.001255  0.001672
#           9          0.116375  0.006548  0.010988  0.238622  0.090144
# ...                       ...       ...       ...       ...       ...
# 45        48         0.000271  0.000832  0.098979  0.000000  0.001702
#           49         0.676598  0.452536  0.010826  0.596688  0.838514
# 47        48         0.870411  0.644795  0.902840  0.612242  0.683142
#           49         0.129589  0.355205  0.097160  0.387758  0.316858
# 48        49         1.000000  1.000000  1.000000  1.000000  1.000000
#
# [861 rows x 5 columns]

# %%
freq_df.loc[8,30]
# Out:
# cancer_type
# coad    0.000142
# esca    0.000829
# paad    0.000972
# read    0.000015
# stad    0.000379
# Name: (8, 30), dtype: float64

# %%
# 1. Define the slicer
idx = pd.IndexSlice

# 2. Slice the dataframe: [Rows(Level1, Level2), Columns]
# This grabs cluster 1 from 8-12 and cluster 2 from 30-35
subset_df = freq_df.loc[idx[8:12, 30:35], :]

# 3. Clean up the format
# Currently 'cluster 1' and 'cluster 2' are indices. 
# To make them regular columns, use reset_index()
select_df = subset_df.reset_index()

select_df
# Out:
# cancer_type  cluster 1  cluster 2      coad      esca      paad      read  \
# 0                    8         30  0.000142  0.000829  0.000972  0.000015
# 1                    8         31  0.000062  0.000747  0.000012  0.000026
# 2                    8         32  0.000023  0.000030  0.000032  0.000011
# 3                    8         33  0.018969  0.009216  0.017912  0.034672
# 4                    8         35  0.000382  0.001131  0.000108  0.000806
# 5                    9         30  0.000125  0.000021  0.000745  0.000119
# 6                    9         31  0.000025  0.000155  0.000052  0.000020
# 7                    9         32  0.000538  0.001562  0.000471  0.000373
# 8                    9         33  0.003870  0.000099  0.000314  0.012942
# 9                    9         35  0.000280  0.000162  0.000405  0.000373
# 10                  10         30  0.000008  0.000011  0.003138  0.000000
# 11                  10         31  0.000000  0.000009  0.000000  0.000000
# 12                  10         32  0.000000  0.000000  0.000000  0.000000
# 13                  10         33  0.000793  0.000270  0.000448  0.002544
# 14                  10         35  0.000096  0.000085  0.000090  0.000000
# 15                  11         30  0.000012  0.000263  0.000152  0.000013
# 16                  11         31  0.000005  0.002014  0.000008  0.000044
# 17                  11         32  0.000010  0.000000  0.000000  0.000000
# 18                  11         33  0.021103  0.008607  0.008229  0.074159
# 19                  11         35  0.000740  0.002513  0.000068  0.000436
# 20                  12         30  0.000218  0.000150  0.000823  0.000122
# 21                  12         31  0.000009  0.000226  0.000013  0.000000
# 22                  12         32  0.000036  0.000081  0.000035  0.000052
# 23                  12         33  0.008230  0.000871  0.001036  0.008416
# 24                  12         35  0.000482  0.000501  0.000252  0.000213
#
# cancer_type      stad
# 0            0.000379
# 1            0.000112
# 2            0.000013
# 3            0.061284
# 4            0.000720
# 5            0.000070
# 6            0.000102
# 7            0.000257
# 8            0.005572
# 9            0.001234
# 10           0.000026
# 11           0.000005
# 12           0.000005
# 13           0.005045
# 14           0.000025
# 15           0.000044
# 16           0.000009
# 17           0.000006
# 18           0.032334
# 19           0.000141
# 20           0.000245
# 21           0.000111
# 22           0.000010
# 23           0.012711
# 24           0.000542

# %%
select_df.mean()
# Out:
# cancer_type
# cluster 1    10.000000
# cluster 2    32.200000
# coad          0.002246
# esca          0.001182
# paad          0.001413
# read          0.005414
# stad          0.004840
# dtype: float64

# %%
freq_df = filtered_df.set_index(['cluster 1','cluster 2','cancer_type'])['frequency'].unstack().fillna(0)

# %%
from scipy.cluster.hierarchy import fcluster

# %%
pal = sns.color_palette('tab20',60)
color1 = [pal[a] for a,b in freq_df.index]
color2 = [pal[b] for a,b in freq_df.index]

# %%
cm = sns.clustermap(np.log2(freq_df+ 0.0001), row_colors = [color1,color2],cmap = 'bwr', vmin = -4, vmax = 0)

# %%
clust_colors = [pal[i] for i in fcluster(cm.dendrogram_row.linkage, t = 20, criterion = 'maxclust')]

# %%
sns.clustermap(np.log10(freq_df+ 0.001), row_colors = [color1,color2, clust_colors])

# %%
plt.figure(figsize=(10, 6))
# log_scale=True automatically calculates logarithmic bins
sns.histplot(data=filtered_df, x='frequency', log_scale=True, kde=True, color='teal')

plt.title('Log-Scaled Distribution of Frequencies for k=60')
plt.xlabel('Frequency (Log Scale)')
plt.ylabel('Count')
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.show()
